# %%
import pandas as pd

# %%
LC_Issuance = pd.read_excel("Trade_Finance_Main.xlsm",skiprows=3,header=0,engine="openpyxl",usecols=['LC Number', 'Issue Date.', 'Project Director', 'Status', 'Bank', 'Facility Space', 'Beneficiary', 'Group Company', 'Project', 'Project Code', 'Curr', 'LC Amt(FCY)', 'Rate', 'LC Amt(SAR)', 'Expiry Date', 'Last Ship Date', 'Lines', 'Payment Terms', 'Cash Margin', 'Cash-Fund Utilized', 'Cash-Recovered', 'Increase Amount in SAR', 'Remarks', 'Active/Cancelled',]
).astype(
    {
        "Project Director":"category",
        "Status":"category",        
        "Bank":"category",
        "Facility Space":"category",
        "Beneficiary":"category",
        "Group Company":"category",
        "Project":"category",
        "Project Code":"Int32",
        "Curr":"category",
        "Lines":"category",
        
    }
)
LC_Issuance["Last Ship Date"] = pd.to_datetime(LC_Issuance["Last Ship Date"]).dt.date
LC_Issuance["Issue Date."] = pd.to_datetime(LC_Issuance["Issue Date."]).dt.date
LC_Issuance["Expiry Date"] = pd.to_datetime(LC_Issuance["Expiry Date"]).dt.date
LC_Issuance
# Out:
# c:\Users\FarhanAmanullaShaikh\PROJECTS\LC-Project\.venv\Lib\site-packages\openpyxl\worksheet\_reader.py:329: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
# c:\Users\FarhanAmanullaShaikh\PROJECTS\LC-Project\.venv\Lib\site-packages\openpyxl\worksheet\_reader.py:329: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)
#         LC Number Issue Date. Project Director             Status    Bank  \
# 0    TF2331987203  2023-11-15     Hassan Taleb          Completed  Alinma
# 1    TF2319983726  2023-07-18     Hassan Taleb          Completed  Alinma
# 2      JLC6901470  2025-08-14    Muhammed Khan          Completed   Riyad
# 3      JLC6801678  2024-09-10    Rabih Makhoul          Completed   Riyad
# 4    IM2431133001  2024-11-13    Rabih Makhoul          Completed     BAB
# ..            ...         ...              ...                ...     ...
# 951           NaN  2026-06-22    Rabih Makhoul  Submitted to Bank     SNB
# 952           NaN  2026-06-23      Nader Ageeb   Received to Open     NBK
# 953           NaN  2026-06-23      Nader Ageeb   Received to Open     NBK
# 954           NaN  2026-06-23      Nader Ageeb   Received to Open     NBK
# 955           NaN  2026-06-23      Nader Ageeb   Received to Open     NBK
#
#     Facility Space                                     Beneficiary  \
# 0              KSP                A. Abunayyan Trading Corporation
# 1              KSP                A. ABUNAYYAN TRADING CORPORATION
# 2             Cash      Abdul Aziz Mohammed Abu Shaiea Trading Est
# 3             Cash             ABDULAH ABDIN ALBUKHARI FACTORY FOR
# 4     Multipurpose   Abdulah Abdin Albukhari Factory For Industry.
# ..             ...                                             ...
# 951    Opera House           Al Arabia Construction & Building Co.
# 952         Lagoon       Al Arabia for Construction & Building Co.
# 953         Lagoon                        INDUSTRIAL STONES SOURCE
# 954         Lagoon                         Modern Material Leaders
# 955         Lagoon  NIZAR ABDALGHANY KABLI FOR GENERAL CONTRACTING
#
#     Group Company                  Project  Project Code  ... Expiry Date  \
# 0       FIRST FIX                      KSP       1020055  ...  2024-05-31
# 1       FIRST FIX                      KSP       1020055  ...  2023-10-16
# 2            IFAS  IFAS - Various Projects          <NA>  ...  2025-09-30
# 3             MBL          Neom - The Line       1020098  ...  2025-02-28
# 4             MBL          Neom - The Line       1020098  ...  2025-01-31
# ..            ...                      ...           ...  ...         ...
# 951           MBL       Rabigh Power Plant       1020107  ...  2026-10-31
# 952           MBL                   Lagoon       1020108  ...  2026-11-21
# 953           MBL                   Lagoon       1020108  ...  2026-11-21
# 954           MBL                   Lagoon       1020108  ...  2026-11-21
# 955           MBL                   Lagoon       1020108  ...  2026-11-21
#
#      Last Ship Date   Lines                    Payment Terms Cash Margin  \
# 0        2024-05-31  Credit       90 Days from Delivery Date         NaN
# 1        2023-10-16  Credit       90 Days from Delivery Date         NaN
# 2        2025-09-15    Cash                            Sight         NaN
# 3        2025-02-10    Cash  45 Days from Comm. Invoice Date  2679704.74
# 4        2025-01-04  Credit        45 Days from Invoice Date         NaN
# ..              ...     ...                              ...         ...
# 951      2026-10-31  Credit    45 Days from the Invoice Date         NaN
# 952      2026-11-21  Credit        90 Days from Invoice Date         NaN
# 953      2026-11-21  Credit        90 Days from Invoice Date         NaN
# 954      2026-11-21  Credit        90 Days from Invoice Date         NaN
# 955      2026-11-21  Credit        90 Days from Invoice Date         NaN
#
#     Cash-Fund Utilized Cash-Recovered Increase Amount in SAR  \
# 0                  NaN            NaN                    0.0
# 1                  NaN            NaN                    0.0
# 2                  NaN            NaN                    NaN
# 3                 Abha            Yes                    0.0
# 4                  NaN            NaN                    0.0
# ..                 ...            ...                    ...
# 951                NaN            NaN                    0.0
# 952                NaN            NaN                    0.0
# 953                NaN            NaN                    0.0
# 954                NaN            NaN                    0.0
# 955                NaN            NaN                    0.0
#
#                                          Remarks Active/Cancelled
# 0                                            NaN        Cancelled
# 1                                            NaN        Cancelled
# 2                Margin refunded - 153759.93 SAR        Cancelled
# 3                                            NaN        Cancelled
# 4                                            NaN        Cancelled
# ..                                           ...              ...
# 951                             to bank on 23-06           Active
# 952  Anil Sir kept on hold for GA | NBK Prepared           Active
# 953  Anil Sir kept on hold for GA | NBK Prepared           Active
# 954  Anil Sir kept on hold for GA | NBK Prepared           Active
# 955  Anil Sir kept on hold for GA | NBK Prepared           Active
#
# [956 rows x 24 columns]

# %%
LC_Issuance.columns
# Out:
# Index(['LC Number', 'Issue Date.', 'Project Director', 'Status', 'Bank',
#        'Facility Space', 'Beneficiary', 'Group Company', 'Project',
#        'Project Code', 'Curr', 'LC Amt(FCY)', 'Rate', 'LC Amt(SAR)',
#        'Expiry Date', 'Last Ship Date', 'Lines', 'Payment Terms',
#        'Cash Margin', 'Cash-Fund Utilized', 'Cash-Recovered',
#        'Increase Amount in SAR', 'Remarks', 'Active/Cancelled'],
#       dtype='str')

# %%
LC_Settlement = pd.read_excel("Trade_Finance_Main.xlsm",sheet_name="Main-Presentation",skiprows=3,header=0,engine="openpyxl")
LC_Settlement
# Out:
# c:\Users\FarhanAmanullaShaikh\PROJECTS\LC-Project\.venv\Lib\site-packages\openpyxl\worksheet\_reader.py:329: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
# c:\Users\FarhanAmanullaShaikh\PROJECTS\LC-Project\.venv\Lib\site-packages\openpyxl\worksheet\_reader.py:329: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)
#              LC Number  Date Recd Presentation No        Project Director  \
# 0         TF2328386224 2024-01-14               1           Mohammed Kotb
# 1         TF2328386224 2024-06-10               2           Mohammed Kotb
# 2         TF2328386224 2024-07-24               3           Mohammed Kotb
# 3         TF2328386224 2024-09-03               4           Mohammed Kotb
# 4         TF2502300031 2025-02-20               1            Hassan Taleb
# ...                ...        ...             ...                     ...
# 1608    JLC6901431_Cre 2026-05-13              11             Luis Puente
# 1609      TF2523000034        NaT             NaN           Rabih Makhoul
# 1610           J212344        NaT             NaN        Matthew Mckernan
# 1611  ILC-0840-26-8758        NaT             NaN  AbdulAziz Eraiba Fawzi
# 1612      DCBWPM165531        NaT             NaN           Mohammed Kotb
#
#      Clean / Disc    Bank Facility Space   Lines  \
# 0           Clean  Alinma            KSP    Cash
# 1           Clean  Alinma            KSP    Cash
# 2           Clean  Alinma            KSP    Cash
# 3      Discrepant  Alinma            KSP    Cash
# 4           Clean  Alinma            KSP  Credit
# ...           ...     ...            ...     ...
# 1608        Clean   Riyad     Oceanarium  Credit
# 1609          NaN  Alinma            KSP  Credit
# 1610          NaN     SNB    Opera House  Credit
# 1611          NaN  Jazira           RCRC  Credit
# 1612          NaN     SAB            MP1  Credit
#
#                                    Beneficiary Group Company  ...  \
# 0                      BRANCH OF TECON LIMITED          ICAD  ...
# 1                      BRANCH OF TECON LIMITED          ICAD  ...
# 2                      BRANCH OF TECON LIMITED          ICAD  ...
# 3                      BRANCH OF TECON LIMITED          ICAD  ...
# 4        ISAM KABBANI & PARTNERS LTD - UNITECH     FIRST FIX  ...
# ...                                        ...           ...  ...
# 1608          Mat Filtrasyon Teknolojeleri A.S           MBL  ...
# 1609     Al Arabia Construction & Building Co.           MBL  ...
# 1610                         Saudi Pro-Kitchen      MBL/ICAD  ...
# 1611                       Green Concrete CJSC           MBL  ...
# 1612  DAIKIN AIR CONDITIONING SAUDI ARABIA LLC      MBL/ICAD  ...
#
#       Invoice Amt (SAR)   Due Date  \
# 0             246726.75 2024-01-08
# 1             176755.45 2024-06-27
# 2             275027.80 2024-07-25
# 3               8510.00 2024-09-19
# 4             500000.00 2025-05-12
# ...                 ...        ...
# 1608          284755.58 2026-07-02
# 1609           48780.61 2026-06-25
# 1610          700000.00 2026-10-19
# 1611          148788.15 2026-10-19
# 1612          735855.00 2026-09-20
#
#                                           Payment Terms  \
# 0                                                     0
# 1                                                     0
# 2                                                     0
# 3                                                     0
# 4                             90 Days from Invoice Date
# ...                                                 ...
# 1608                          45 Days from Invoice Date
# 1609                      45 Days from the Invoice Date
# 1610  120 Days from Applicant representative sign on...
# 1611                          60 Days From Invoice Date
# 1612             90 Days from Appln Rep Sign on Invoice
#
#                           Funds Utilize Recovered Remarks  Days  Tariff  \
# 0                                  Abha       Yes     NaN     0     NaN
# 1                                  Abha       Yes     NaN     0     NaN
# 2                                  Abha       Yes     NaN     0     NaN
# 3                                  Abha       Yes     NaN     0     NaN
# 4     JLC6800561-ADF Cash Margin Refund        No     NaN    90     NaN
# ...                                 ...       ...     ...   ...     ...
# 1608                                NaN        No     NaN    45     NaN
# 1609                                NaN        No     NaN    45     NaN
# 1610                                NaN        No     NaN   120     NaN
# 1611                                NaN        No     NaN    60     NaN
# 1612                                NaN        No     NaN    90     NaN
#
#       Settlement Charges Other Charges
# 0                1437.50           NaN
# 1                1437.50           NaN
# 2                1437.50           NaN
# 3                1437.50           NaN
# 4                1437.50           NaN
# ...                  ...           ...
# 1608              818.80           NaN
# 1609            34827.75           NaN
# 1610          2505602.75           NaN
# 1611           106930.45           NaN
# 1612             3172.85           NaN
#
# [1613 rows x 28 columns]
